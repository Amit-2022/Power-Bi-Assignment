# %% [markdown]
# Objective – Power BI Desktop, Cloud Service and End to End Workflow Use Case – Series Insights Source – Series File
# Analytics – Ranking Series
# Report/Dashboard – Series Insights
# • Create a measure (not a calculated column) to rank each series by its viewing figures to get:
# Result – Creating new measure and using DAX to calculate the ranking.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
