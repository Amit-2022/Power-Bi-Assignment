# %% [markdown]
# Objective – Power BI Desktop, Cloud Service and End to End Workflow Use Case – Product Information Source – Incomplete Report
# Analytics – Fill in three time intelligence functions in a report
# Report/Dashboard – Product Insights
# • Create 3 measures using the table - the screen shot below shows what these should show. Here are the measures you need to create:
# The below is the snapshot of how the output should look like –
# Result – Creating new measures and using DAX to calculate the time intelligence functions.

# %% [markdown]
# ![image.png](attachment:image.png)
