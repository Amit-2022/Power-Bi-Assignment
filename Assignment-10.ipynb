# %% [markdown]
# Objective – Power BI Desktop, Cloud Service and End to End Workflow Use Case – Information about Films Source – List of Films, ComfortBreaks
# Analytics – To find average number of breaks for a film
# Report/Dashboard – Film Insights
# • It contains a table giving how many times the author would need to pop out for a comfort break during each film's screening:
# From this table you should be able to make a reasonable guess at the author's age ...
# • In the Films table create a calculated column called NumberBreaks which shows for each film the number of breaks needed.
# When you've finished, you should be able to create the following matrix:
# • try creating a second calculated column to do the same thing, but this time using the method you didn't use the first time.
# Result – Creating new calculated columns using DAX

# %% [markdown]
# ![image.png](attachment:image.png)
