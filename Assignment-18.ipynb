# %% [markdown]
# Objective: Power BI Desktop, Cloud Service and End to End Workflow.
# Topic: Charts. Exercise: Show a chart comparing films when you click on each genre in a tree map.
# • Create a new Power BI report. Load the worksheets from the workbook in the above folder, and use them to create a data model.
# • Now create a table and matrix, such that when you click on a continent (such as Africa for this example) you see the number of events in each of its countries, by year.

# %% [markdown]
# ![image.png](attachment:image.png)
