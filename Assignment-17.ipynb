# %% [markdown]
# Objective: Power BI Desktop, Cloud Service and End to End Workflow.
# Topic: Filtering Data.
# Exercise: Create a slicer and chart to choose which whale sightings dataset to see.
# • Create a new Power BI Desktop file, and load into it sightings of whales and porpoises from the Whale and Dolphin Trust.
# • Create a slicer based on the data allowing you to choose the species sighted.
# • Now add a chart comparing sightings by month, but restrict this by choosing the slicer species shown.

# %% [markdown]
# ![image.png](attachment:image.png)
