# %% [markdown]
# Objective: Power BI Desktop, Cloud Service and End to End Workflow.
# Topic: Calculated Columns.
# Exercise: Use the RELATED function to combine fields from four tables.
# • Create a new Power BI report and load the data from the Excel file provided.
# • In model view, create the obvious relationships between the tables.
# • Using the RELATED function, create calculated columns in the Event table to bring in the country, continent and category for each event to get this:
# • Create a matrix to show the number of events and continent.

# %% [markdown]
# ![image.png](attachment:image.png)
